# %% [markdown]
# ### Demo: load a server trained model; score locally

# %%
import os, sys
from fastai.vision import *
from IPython.display import display
import imutils, PIL
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# defaults.device = torch.device('cpu')

# %%
path = Path('data/bears')
img = open_image(path/'blackbear_1.jpg')
img
# Out:
# Image (3, 274, 184)

# %%
learn = load_learner(path)

# %%
predict_output = learn.predict(img)
print(*predict_output, sep='\n')
# Out:
# black
# tensor(0)
# tensor([9.4784e-01, 5.2144e-02, 1.7873e-05])

# %% [markdown]
# #### funny examples

# %%
imgs = []

path2 = Path('../../../../../sut-pics/')
imgs.append(open_image(path2/'sut2.jpg'))

imgs.append(open_image(path/'bri_resize.jpg'))

imgs.append(open_image(path/'bishop_1.jpg'))

for _img in imgs:
    _img.resize(224)

display(*imgs)
# Out:
# Image (3, 544, 356)
# Image (3, 300, 400)
# Image (3, 1270, 1588)

# %%
preds = []
for _i, _img in enumerate(imgs):
    _pred = learn.predict(_img)
    preds.append(_pred)
    print('IMG-%i is %s' % (_i, str(_pred[0])) )
# Out:
# IMG-0 is black
# IMG-1 is black
# IMG-2 is teddys

# %%
for _pred in preds:
    plt.bar(
        x=learn.data.classes,
        height=_pred[2]
    )
    plt.show()
